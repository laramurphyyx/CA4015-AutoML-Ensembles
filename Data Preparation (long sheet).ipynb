# %%
import matplotlib.pyplot as plt

# pandas and numpy for data manipulation
import pandas as pd
import numpy as np

# Import the tpot regressor
from tpot import TPOTRegressor

# %%
data = pd.read_excel('data/raw_data.xlsx')

# %%
data.head()
# Out:
#   The data on this sheet was used to formulate Figure 2, Figure 3, Figure S1 - S10  \
# 0                                                NaN
# 1                                          Compounds
# 2                                      Ethyl Acetate
# 3                                            Ethanol
# 4                        Propanoic acid, ethyl ester
#
#                Unnamed: 1   Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0                     NaN          NaN         NaN         NaN         NaN
# 1          Chemical_class          NaN         NaN  SA.A_TSB_A  SA.A_TSB_B
# 2                   Ester  888±8 (234)        43.0      465374      193151
# 3                 Alcohol      932±8 (        45.0     1027715     1050974
# 4  Fatty acid ethyl ester   953±7 (87)        57.0         NaN         NaN
#
#    Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ... Unnamed: 78  \
# 0         NaN         NaN         NaN         NaN  ...         NaN
# ...

# %%
new_data_1 = data.swapaxes("index", "columns")

# %%
new_data_1
# Out:
#                                                      0               1   \
# The data on this sheet was used to formulate Fi...  NaN       Compounds
# Unnamed: 1                                          NaN  Chemical_class
# Unnamed: 2                                          NaN             NaN
# Unnamed: 3                                          NaN             NaN
# Unnamed: 4                                          NaN      SA.A_TSB_A
# ...                                                 ...             ...
# Unnamed: 83                                         NaN      EC.B_TSB_A
# Unnamed: 84                                         NaN      EC.B_TSB_B
# Unnamed: 85                                         NaN      EC.B_TSB_C
# Unnamed: 86                                         NaN      EC.B_TSB_D
# Unnamed: 87                                         NaN      EC.B_TSB_E
#
#                                                                 2        3   \
# ...

# %%
columns_1 = new_data_1.iloc[0]

# %%
columns_2 = new_data_1.iloc[1]

# %%
type(columns_2)
# Out:
# pandas.core.series.Series

# %%
columns_1.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 64    False
# 65    False
# 66    False
# 67    False
# 68    False
# Name: The data on this sheet was used to formulate Figure 2, Figure 3, Figure S1 - S10, Length: 69, dtype: bool

# %%
new_data_1
# Out:
#                                                      0               1   \
# The data on this sheet was used to formulate Fi...  NaN       Compounds
# Unnamed: 1                                          NaN  Chemical_class
# Unnamed: 2                                          NaN             NaN
# Unnamed: 3                                          NaN             NaN
# Unnamed: 4                                          NaN      SA.A_TSB_A
# ...                                                 ...             ...
# Unnamed: 83                                         NaN      EC.B_TSB_A
# Unnamed: 84                                         NaN      EC.B_TSB_B
# Unnamed: 85                                         NaN      EC.B_TSB_C
# Unnamed: 86                                         NaN      EC.B_TSB_D
# Unnamed: 87                                         NaN      EC.B_TSB_E
#
#                                                                 2        3   \
# ...

# %%
actual_data = new_data_1.iloc[2:,1:]

# %%
actual_data.shape
# Out:
# (86, 68)

# %%
len(columns_1)
# Out:
# 69

# %%
column_names = columns_1[1:]

# %%
actual_data.columns = column_names

# %%
actual_data
# Out:
# The data on this sheet was used to formulate Figure 2, Figure 3, Figure S1 - S10   Compounds  \
# Unnamed: 2                                                                               NaN
# Unnamed: 3                                                                               NaN
# Unnamed: 4                                                                        SA.A_TSB_A
# Unnamed: 5                                                                        SA.A_TSB_B
# Unnamed: 6                                                                        SA.A_TSB_C
# ...                                                                                      ...
# Unnamed: 83                                                                       EC.B_TSB_A
# Unnamed: 84                                                                       EC.B_TSB_B
# Unnamed: 85                                                                       EC.B_TSB_C
# ...

# %%
actual_data.drop(1, axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13228/1108849560.py in <module>
# ----> 1 actual_data.drop(1, axis=1)
#
# ~\AppData\Local\Continuum\anaconda3\envs\ca4015\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\AppData\Local\Continuum\anaconda3\envs\ca4015\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ...

# %%
actual_data.set_index(range(1,87))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13228/24426906.py in <module>
# ----> 1 actual_data.set_index(range(1,87))
#
# ~\AppData\Local\Continuum\anaconda3\envs\ca4015\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\AppData\Local\Continuum\anaconda3\envs\ca4015\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5449
#    5450         if missing:
# -> 5451             raise KeyError(f"None of {missing} are in the columns")
#    5452
#    5453         if inplace:
#
# KeyError: 'None of [range(1, 87)] are in the columns'

# %%
actual_data = actual_data.reset_index()

# %%
actual_data.drop("index", axis=1)
# Out:
# The data on this sheet was used to formulate Figure 2, Figure 3, Figure S1 - S10   Compounds  \
# 0                                                                                        NaN
# 1                                                                                        NaN
# 2                                                                                 SA.A_TSB_A
# 3                                                                                 SA.A_TSB_B
# 4                                                                                 SA.A_TSB_C
# ..                                                                                       ...
# 81                                                                                EC.B_TSB_A
# 82                                                                                EC.B_TSB_B
# 83                                                                                EC.B_TSB_C
# ...

# %%
actual_data.isna().sum()
# Out:
# The data on this sheet was used to formulate Figure 2, Figure 3, Figure S1 - S10
# index                           0
# Compounds                       2
#  Ethyl Acetate                  1
# Ethanol                         0
# Propanoic acid, ethyl ester    57
#                                ..
# n-Tridecan-1-ol                57
# 1-Tetradecanol                 57
# n-Pentadecanol                 58
#  1-Hexadecanol                 57
# Indole                         57
# Length: 69, dtype: int64
