# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('raw_data.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19428/1354964530.py in <module>
# ----> 1 data = pd.read_csv('raw_data.csv')
#
# ~\AppData\Local\Continuum\anaconda3\envs\ca4015\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\AppData\Local\Continuum\anaconda3\envs\ca4015\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~\AppData\Local\Continuum\anaconda3\envs\ca4015\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~\AppData\Local\Continuum\anaconda3\envs\ca4015\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~\AppData\Local\Continuum\anaconda3\envs\ca4015\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~\AppData\Local\Continuum\anaconda3\envs\ca4015\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in __init__(self, src, **kwds)
#      67         kwds["dtype"] = ensure_dtype_objs(kwds.get("dtype", None))
#      68         try:
# ---> 69             self._reader = parsers.TextReader(self.handles.handle, **kwds)
#      70         except Exception:
#      71             self.handles.close()
#
# ~\AppData\Local\Continuum\anaconda3\envs\ca4015\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# ~\AppData\Local\Continuum\anaconda3\envs\ca4015\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._get_header()
#
# ~\AppData\Local\Continuum\anaconda3\envs\ca4015\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# ~\AppData\Local\Continuum\anaconda3\envs\ca4015\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc5 in position 14: invalid continuation byte

# %%
import chardet
with open('raw_data.csv', 'rb') as rawdata:
    result = chardet.detect(rawdata.read(100000))
result
# Out:
# {'encoding': None, 'confidence': 0.0, 'language': None}

# %%
import chardet
with open('raw_data.xlsx', 'rb') as rawdata:
    result = chardet.detect(rawdata.read(100000))
result
# Out:
# {'encoding': None, 'confidence': 0.0, 'language': None}

# %%
data = pd.read_excel('raw_data.xlsx')

# %%
data
# Out:
#    The data on this sheet was used to formulate Figure 2, Figure 3, Figure S1 - S10  \
# 0                                                 NaN
# 1                                           Compounds
# 2                                       Ethyl Acetate
# 3                                             Ethanol
# 4                         Propanoic acid, ethyl ester
# ..                                                ...
# 64                                    n-Tridecan-1-ol
# 65                                     1-Tetradecanol
# 66                                     n-Pentadecanol
# 67                                      1-Hexadecanol
# 68                                             Indole
#
#                 Unnamed: 1    Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0                      NaN           NaN         NaN         NaN         NaN
# 1           Chemical_class           NaN         NaN  SA.A_TSB_A  SA.A_TSB_B
# 2                    Ester   888±8 (234)        43.0      465374      193151
# 3                  Alcohol       932±8 (        45.0     1027715     1050974
# 4   Fatty acid ethyl ester    953±7 (87)        57.0         NaN         NaN
# ..                     ...           ...         ...         ...         ...
# 64                 Alcohol       2074±20        55.0         NaN         NaN
# 65                 Alcohol  2165±10 (27)        55.0         NaN         NaN
# 66                 Alcohol       2254±15        83.0         NaN         NaN
# 67                 Alcohol   2382±5 (49)        83.0         NaN         NaN
# 68                  Indole  2445±10 (46)       117.0         NaN         NaN
#
#     Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ... Unnamed: 78  \
# 0          NaN         NaN         NaN         NaN  ...         NaN
# 1   SA.A_TSB_C  SA.A_TSB_D  SA.A_TSB_E  SA.B_TSB_A  ...  EC.A_TSB_A
# 2       403286      129833      117105      316764  ...      887825
# 3      1850391     5140770     3422557      914667  ...     7585417
# 4          NaN         NaN         NaN         NaN  ...           0
# ..         ...         ...         ...         ...  ...         ...
# 64         NaN         NaN         NaN         NaN  ...           0
# 65         NaN         NaN         NaN         NaN  ...      851004
# 66         NaN         NaN         NaN         NaN  ...           0
# 67         NaN         NaN         NaN         NaN  ...      850885
# 68         NaN         NaN         NaN         NaN  ...    88277609
#
#    Unnamed: 79 Unnamed: 80 Unnamed: 81 Unnamed: 82 Unnamed: 83 Unnamed: 84  \
# 0          NaN         NaN         NaN         NaN         NaN         NaN
# 1   EC.A_TSB_B  EC.A_TSB_C  EC.A_TSB_D  EC.A_TSB_E  EC.B_TSB_A  EC.B_TSB_B
# 2       670603      576884      636851         NaN      119313      128397
# 3      7461659     2372532     5114072     7870420     1364553     1451138
# 4            0           0           0           0           0           0
# ..         ...         ...         ...         ...         ...         ...
# 64           0           0           0           0           0           0
# 65      922978      593032      450711      843660           0       78672
# 66           0           0           0           0           0           0
# 67     1183943      382201      390122     1033300           0           0
# 68    91230943   109912287    89285823    82182776    60325589   107880324
#
#    Unnamed: 85 Unnamed: 86 Unnamed: 87
# 0          NaN         NaN         NaN
# 1   EC.B_TSB_C  EC.B_TSB_D  EC.B_TSB_E
# 2       309004      548442      339404
# 3      5650813     3588158     3962927
# 4            0           0           0
# ..         ...         ...         ...
# 64           0           0           0
# 65       84426      146349      635257
# 66           0           0           0
# 67           0           0      482026
# 68    72102392    85257546    97156549
#
# [69 rows x 88 columns]
